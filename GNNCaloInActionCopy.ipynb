# %% [markdown]
# ## Required package

# %%
#import uproot
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from scipy.spatial.distance import cdist
from sklearn.model_selection import cross_val_score, cross_val_predict, train_test_split
from collections import namedtuple, defaultdict
#import open3d as o3d
import random
random.seed(42)
import h5py
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv
from torch_geometric.utils import add_self_loops
from torch_geometric.transforms import ToUndirected
from torchvision import transforms
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import joblib
from torch.nn import BatchNorm1d
from torch.optim.lr_scheduler import LambdaLR
import pickle
#Import needed python libraries.

# %%
from ipynb.fs.full.GeneralFunctions import CustomDataset, collate, collate_true, collate_bkg_lone, collate_bkg_cluster_lone, collate_bkg_cluster_cluster, collate_bkg_total, EdgeClassifier, lr_schedule, train, testModel, pickleData, makeTruthArray

# %% [markdown]
# ## Required data generated by GNNonCalo_Scaling_DataPreparation.ipynb

# %%
hf_cellFeaturesScaled_neighbor= h5py.File("./cellFeaturesScaled_train_70evs_all2D.hdf5", 'r')
hf_train_edge_source_BD = h5py.File("./train_edge_source_BD_70evs_all2D.hdf5", 'r')
hf_train_edge_dest_BD = h5py.File("./train_edge_dest_BD_70evs_all2D.hdf5", 'r')
hf_train_edge_source_noBD = h5py.File("./train_edge_source_noBD_70evs_all2D.hdf5", 'r')
hf_train_edge_dest_noBD = h5py.File("./train_edge_dest_noBD_70evs_all2D.hdf5", 'r')
hf_truth_label_train_neighbor= h5py.File("./truth_label_train_70evs_all2D.hdf5", 'r')
#Open needed hdf5 files.

# %%
cellFeaturesScaled = hf_cellFeaturesScaled_neighbor.get("cellFeatures_trainS")[:]
train_edge_source_BD = hf_train_edge_source_BD.get("train_edge_source_BD")[:]
train_edge_dest_BD = hf_train_edge_dest_BD.get("train_edge_dest_BD")[:]
train_edge_source_noBD = hf_train_edge_source_noBD.get("train_edge_source_noBD")[:]
train_edge_dest_noBD = hf_train_edge_dest_noBD.get("train_edge_dest_noBD")[:]
truth_label_train = hf_truth_label_train_neighbor.get("truth_label_train")[:]
#Pull the data from hdf5 files as arrays.

# %%
hf_cellFeaturesScaled_neighbor.close()
hf_train_edge_source_BD.close()
hf_train_edge_dest_BD.close()
hf_train_edge_source_noBD.close()
hf_train_edge_dest_noBD.close()
hf_truth_label_train_neighbor.close()
#Close hdf5 files.

# %%
hf_test_edge_source_true_BD = h5py.File("./test_edge_source_true_BD_all2D.hdf5", "r")
hf_test_edge_dest_true_BD = h5py.File("./test_edge_dest_true_BD_all2D.hdf5", "r")
hf_test_edge_source_true_noBD = h5py.File("./test_edge_source_true_noBD_all2D.hdf5", "r")
hf_test_edge_dest_true_noBD = h5py.File("./test_edge_dest_true_noBD_all2D.hdf5", "r")

hf_test_edge_source_bkg_lone_BD = h5py.File("./test_edge_source_bkg_lone_BD_all2D.hdf5", "r")
hf_test_edge_dest_bkg_lone_BD = h5py.File("./test_edge_dest_bkg_lone_BD_all2D.hdf5", "r")
hf_test_edge_source_bkg_lone_noBD = h5py.File("./test_edge_source_bkg_lone_noBD_all2D.hdf5", "r")
hf_test_edge_dest_bkg_lone_noBD = h5py.File("./test_edge_dest_bkg_lone_noBD_all2D.hdf5", "r")

hf_test_edge_source_bkg_cluster_lone_BD = h5py.File("./test_edge_source_bkg_cluster_lone_BD_all2D.hdf5", "r")
hf_test_edge_dest_bkg_cluster_lone_BD = h5py.File("./test_edge_dest_bkg_cluster_lone_BD_all2D.hdf5", "r")
hf_test_edge_source_bkg_cluster_lone_noBD = h5py.File("./test_edge_source_bkg_cluster_lone_noBD_all2D.hdf5", "r")
hf_test_edge_dest_bkg_cluster_lone_noBD = h5py.File("./test_edge_dest_bkg_cluster_lone_noBD_all2D.hdf5", "r")

hf_test_edge_source_bkg_cluster_cluster_BD = h5py.File("./test_edge_source_bkg_cluster_cluster_BD_all2D.hdf5", "r")
hf_test_edge_dest_bkg_cluster_cluster_BD = h5py.File("./test_edge_dest_bkg_cluster_cluster_BD_all2D.hdf5", "r")
hf_test_edge_source_bkg_cluster_cluster_noBD = h5py.File("./test_edge_source_bkg_cluster_cluster_noBD_all2D.hdf5", "r")
hf_test_edge_dest_bkg_cluster_cluster_noBD = h5py.File("./test_edge_dest_bkg_cluster_cluster_noBD_all2D.hdf5", "r")

# %%
test_edge_source_true_BD = hf_test_edge_source_true_BD.get("test_edge_source_true_BD")[:]
test_edge_dest_true_BD = hf_test_edge_dest_true_BD.get("test_edge_dest_true_BD")[:]
test_edge_source_true_noBD = hf_test_edge_source_true_noBD.get("test_edge_source_true_noBD")[:]
test_edge_dest_true_noBD = hf_test_edge_dest_true_noBD.get("test_edge_dest_true_noBD")[:]

test_edge_source_bkg_lone_BD = hf_test_edge_source_bkg_lone_BD.get("test_edge_source_bkg_lone_BD")[:]
test_edge_dest_bkg_lone_BD = hf_test_edge_dest_bkg_lone_BD.get("test_edge_dest_bkg_lone_BD")[:]
test_edge_source_bkg_lone_noBD = hf_test_edge_source_bkg_lone_noBD.get("test_edge_source_bkg_lone_noBD")[:]
test_edge_dest_bkg_lone_noBD = hf_test_edge_dest_bkg_lone_noBD.get("test_edge_dest_bkg_lone_noBD")[:]

test_edge_source_bkg_cluster_lone_BD = hf_test_edge_source_bkg_cluster_lone_BD.get("test_edge_source_bkg_cluster_lone_BD")[:]
test_edge_dest_bkg_cluster_lone_BD = hf_test_edge_dest_bkg_cluster_lone_BD.get("test_edge_dest_bkg_cluster_lone_BD")[:]
test_edge_source_bkg_cluster_lone_noBD = hf_test_edge_source_bkg_cluster_lone_noBD.get("test_edge_source_bkg_cluster_lone_noBD")[:]
test_edge_dest_bkg_cluster_lone_noBD = hf_test_edge_dest_bkg_cluster_lone_noBD.get("test_edge_dest_bkg_cluster_lone_noBD")[:]

test_edge_source_bkg_cluster_cluster_BD = hf_test_edge_source_bkg_cluster_cluster_BD.get("test_edge_source_bkg_cluster_cluster_BD")[:]
test_edge_dest_bkg_cluster_cluster_BD = hf_test_edge_dest_bkg_cluster_cluster_BD.get("test_edge_dest_bkg_cluster_cluster_BD")[:]
test_edge_source_bkg_cluster_cluster_noBD = hf_test_edge_source_bkg_cluster_cluster_noBD.get("test_edge_source_bkg_cluster_cluster_noBD")[:]
test_edge_dest_bkg_cluster_cluster_noBD = hf_test_edge_dest_bkg_cluster_cluster_noBD.get("test_edge_dest_bkg_cluster_cluster_noBD")[:]

# %%
hf_test_edge_source_true_BD.close()
hf_test_edge_dest_true_BD.close()
hf_test_edge_source_true_noBD.close()
hf_test_edge_dest_true_noBD.close()

hf_test_edge_source_bkg_lone_BD.close()
hf_test_edge_dest_bkg_lone_BD.close()
hf_test_edge_source_bkg_lone_noBD.close()
hf_test_edge_dest_bkg_lone_noBD.close() 

hf_test_edge_source_bkg_cluster_lone_BD.close()
hf_test_edge_dest_bkg_cluster_lone_BD.close()
hf_test_edge_source_bkg_cluster_lone_noBD.close()
hf_test_edge_dest_bkg_cluster_lone_noBD.close()

hf_test_edge_source_bkg_cluster_cluster_BD.close()
hf_test_edge_dest_bkg_cluster_cluster_BD.close()
hf_test_edge_source_bkg_cluster_cluster_noBD.close()
hf_test_edge_dest_bkg_cluster_cluster_noBD.close()

# %%
cellFeaturesScaled.shape
#Print the shape of the cellFeaturesScaled array.
# Out:
# (70, 187652, 8)

# %%
cellFeaturesScaled[2][1]
#Print an element of the cellFeaturesScaled array.
# Out:
# array([0.58421445, 0.51289224, 0.16380877, 0.23466876, 0.52418755,
#        0.26086957, 0.09700815, 0.22900586])

# %%
x = torch.tensor(cellFeaturesScaled, dtype=torch.float)
#Convert cellFeaturesScaled into a torch tensor called x.

# %%
x.shape
#Print the shape of x.
# Out:
# torch.Size([70, 187652, 8])

# %%
train_edge_source_BD.shape
#Print the shape of train_edge_source_BD.
# Out:
# (70, 89600)

# %% [markdown]
# ## Preparing bi directional edges (align source and destination) for GNN

# %%
edge_index = torch.tensor([train_edge_source_BD, train_edge_dest_BD], dtype=torch.long)
#Create a torch tensor called edge_index out of train_edge_source_BD and train_edge_dest_BD.
# Out:
# /tmp/ipykernel_1179425/3873013880.py:1: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:274.)
#   edge_index = torch.tensor([train_edge_source_BD, train_edge_dest_BD], dtype=torch.long)

# %%
edge_index.shape
#Print the shape of edge_index.
# Out:
# torch.Size([2, 70, 89600])

# %%
edge_index_ch = edge_index.permute(1, 0, 2)
#Make a new torch tensor called edge_index_ch by permuting the dimensions of edge_index.

# %%
edge_index_ch.shape
#Print the shape of edge_index_ch.
# Out:
# torch.Size([70, 2, 89600])

# %% [markdown]
# ## Preparing uni directional edges for final binary classification

# %%
edge_index_out = torch.tensor([train_edge_source_noBD, train_edge_dest_noBD], dtype=torch.long)
#Create a torch tensor called edge_index_out out of train_edge_source_noBD and train_edge_dest_noBD.

# %%
edge_index_out.shape
#Print the shape of edge_index_out.
# Out:
# torch.Size([2, 70, 44800])

# %%
edge_index_out_ch = edge_index_out.permute(1, 0, 2)
#Make a new torch tensor called edge_index_out_ch by permuting the dimensions of edge_index_out.

# %%
edge_index_out_ch.shape
#Print the shape of edge_index_out_ch.
# Out:
# torch.Size([70, 2, 44800])

# %% [markdown]
# ## Preparing label (true/Fake) tensor

# %%
truth_label_train = np.expand_dims(truth_label_train, axis=1)
#Expands the dimensions of truth_label_train.

# %%
truth_label_train.shape
#Prints the shape of truth_label_train.
# Out:
# (70, 1, 44800)

# %%
y_train = torch.tensor(truth_label_train, dtype=torch.float)
#Converts truth_label_train into a torch tensor named y_train.

# %%
y_train.shape
#Prints the shape of y_train.
# Out:
# torch.Size([70, 1, 44800])

# %% [markdown]
# ## Data customization specific to pytorch

# %%
# Generate data_list
data_list = []
for i in range(70):
    x_mat = x[i]
    edge_index = edge_index_ch[i]
    edge_index, _ = add_self_loops(edge_index)
    data = Data(x=x_mat, edge_index=edge_index, edge_index_out = edge_index_out_ch[i], y=y_train[i])
    data = ToUndirected()(data)
    data_list.append(data)

# %%
ind0 = data_list[0].edge_index
ind1 = data_list[1].edge_index
ind2 = data_list[2].edge_index

# %%
print(ind0.shape)
print(ind1.shape)
print(ind2.shape)
# Out:
# torch.Size([2, 277248])
# torch.Size([2, 277232])
# torch.Size([2, 277235])

# %%
custom_dataset = CustomDataset(data_list)

# %%
batch_size = 20
data_loader = torch.utils.data.DataLoader(custom_dataset, batch_size=batch_size, collate_fn=collate)
#Formats the data and loads it into a data_loader. I’m honestly not sure about some of the details here.

# %%
for batch_x, batch_edge_index, batch_edge_index_out, _ in data_loader:
    print(len(batch_edge_index))
# Out:
# 20
# 20
# 20
# 10

# %%
#y_test.shape

# %%
data.edge_index.shape
# Out:
# torch.Size([2, 277250])

# %%
data.y.shape
# Out:
# torch.Size([1, 44800])

# %%
x.size(1)
#Prints some information about the shape of the data.
# Out:
# 187652

# %%
edge_index_true = torch.tensor([test_edge_source_true_BD, test_edge_dest_true_BD], dtype=torch.long)
edge_index_bkg_lone = torch.tensor([test_edge_source_bkg_lone_BD, test_edge_dest_bkg_lone_BD], dtype=torch.long)
edge_index_bkg_cluster_lone = torch.tensor([test_edge_source_bkg_cluster_lone_BD, test_edge_dest_bkg_cluster_lone_BD], dtype=torch.long)
edge_index_bkg_cluster_cluster = torch.tensor([test_edge_source_bkg_cluster_cluster_BD, test_edge_dest_bkg_cluster_cluster_BD], dtype=torch.long)

# %%
edge_index_true_ch = edge_index_true.permute(1, 0, 2)
edge_index_bkg_lone_ch = edge_index_bkg_lone.permute(1, 0, 2)
edge_index_bkg_cluster_lone_ch = edge_index_bkg_cluster_lone.permute(1, 0, 2)
edge_index_bkg_cluster_cluster_ch = edge_index_bkg_cluster_cluster.permute(1, 0, 2)

# %%
edge_index_true_out = torch.tensor([test_edge_source_true_noBD, test_edge_dest_true_noBD], dtype=torch.long)
edge_index_bkg_lone_out = torch.tensor([test_edge_source_bkg_lone_noBD, test_edge_dest_bkg_lone_noBD], dtype=torch.long)
edge_index_bkg_cluster_lone_out = torch.tensor([test_edge_source_bkg_cluster_lone_noBD, test_edge_dest_bkg_cluster_lone_noBD], dtype=torch.long)
edge_index_bkg_cluster_cluster_out = torch.tensor([test_edge_source_bkg_cluster_cluster_noBD, test_edge_dest_bkg_cluster_cluster_noBD], dtype=torch.long)

# %%
edge_index_true_out_ch = edge_index_true_out.permute(1, 0, 2)
edge_index_bkg_lone_out_ch = edge_index_bkg_lone_out.permute(1, 0, 2)
edge_index_bkg_cluster_lone_out_ch = edge_index_bkg_cluster_lone_out.permute(1, 0, 2)
edge_index_bkg_cluster_cluster_out_ch = edge_index_bkg_cluster_cluster_out.permute(1, 0, 2)

# %%
edge_index_bkg_cluster_cluster_out_ch.shape
# Out:
# torch.Size([30, 2, 1900])

# %%
y_test_bkg_lone = makeTruthArray(edge_index_bkg_lone_out_ch, False)

# %%
y_test_bkg_cluster_lone = makeTruthArray(edge_index_bkg_cluster_lone_out_ch, False)

# %%
y_test_bkg_cluster_cluster = makeTruthArray(edge_index_bkg_cluster_cluster_out_ch, False)

# %%
y_test_true = makeTruthArray(edge_index_true_out_ch, True)

# %%
data_list_true = []
for i in range(30):
    x_mat = x[i]
    edge_index = edge_index_true_ch[i]
    edge_index, _ = add_self_loops(edge_index)
    data = Data(x=x_mat, edge_index=edge_index, edge_index_out = edge_index_true_out_ch[i], y= y_test_true[i])
    data = ToUndirected()(data)
    data_list_true.append(data)

# %%
data_list_bkg_lone = []
for i in range(30):
    x_mat = x[i]
    edge_index = edge_index_bkg_lone_ch[i]
    edge_index, _ = add_self_loops(edge_index)
    data = Data(x=x_mat, edge_index=edge_index, edge_index_out = edge_index_bkg_lone_out_ch[i], y = y_test_bkg_lone[i])
    data = ToUndirected()(data)
    data_list_bkg_lone.append(data)

# %%
data_list_bkg_cluster_lone = []
for i in range(30):
    x_mat = x[i]
    edge_index = edge_index_bkg_cluster_lone_ch[i]
    edge_index, _ = add_self_loops(edge_index)
    data = Data(x=x_mat, edge_index=edge_index, edge_index_out = edge_index_bkg_cluster_lone_out_ch[i], y = y_test_bkg_cluster_lone[i])
    data = ToUndirected()(data)
    data_list_bkg_cluster_lone.append(data)

# %%
data_list_bkg_cluster_cluster = []
for i in range(30):
    x_mat = x[i]
    edge_index = edge_index_bkg_cluster_cluster_ch[i]
    edge_index, _ = add_self_loops(edge_index)
    data = Data(x=x_mat, edge_index=edge_index, edge_index_out = edge_index_bkg_cluster_cluster_out_ch[i], y = y_test_bkg_cluster_cluster[i])
    data = ToUndirected()(data)
    data_list_bkg_cluster_cluster.append(data)

# %%
custom_dataset_true = CustomDataset(data_list_true)
#custom_dataset_bkg_lone = CustomDataset(data_list_bkg_lone)
#custom_dataset_bkg_cluster_lone = CustomDataset(data_list_bkg_cluster_lone)
#custom_dataset_bkg_cluster_cluster = CustomDataset(data_list_bkg_cluster_cluster)

# %%
batch_size = 20
data_loader_true = torch.utils.data.DataLoader(custom_dataset_true, batch_size = batch_size, collate_fn = collate_true)
#data_loader_bkg_lone = torch.utils.data.DataLoader(custom_dataset_bkg_lone, batch_size = batch_size, collate_fn = collate_bkg_lone)
#data_loader_bkg_cluster_lone = torch.utils.data.DataLoader(custom_dataset_bkg_cluster_lone, batch_size = batch_size, collate_fn = collate_bkg_cluster_lone)
#data_loader_bkg_cluster_cluster = torch.utils.data.DataLoader(custom_dataset_bkg_cluster_cluster, batch_size = batch_size, collate_fn = collate_bkg_cluster_cluster)

# %%
data_list_total_bkg = data_list_bkg_lone + data_list_bkg_cluster_lone + data_list_bkg_cluster_cluster

# %%
custom_dataset_total_bkg = CustomDataset(data_list_total_bkg)

# %%
data_loader_total_bkg = torch.utils.data.DataLoader(custom_dataset_total_bkg, batch_size = batch_size, collate_fn = collate_bkg_total)

# %% [markdown]
# ## Edge Classifier Model

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Instantiate the model
input_dim = 8
hidden_dim = 256
output_dim = 1  # Binary classification (citing or not citing)
model = EdgeClassifier(input_dim, hidden_dim, output_dim)

# Define the loss function and optimizer
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)

# Define the learning rate scheduler
scheduler = LambdaLR(optimizer, lr_lambda=lr_schedule)
#Sets up the GPU. Creates an edge classifier with 8 input dimensions, 256 hidden dimensions, and 1 output dimensions. Create a loss function
#(binary cross entropy) and optimizer (Adam). Uses lambdaLR to create a scheduler.

# %%
num_epochs = 500
lossPerEpochTraining = []
scores = []
truth_labels = []
allLossPerEpochTestTrue = []
allLossPerEpochTestBackground = []
for epoch in range(num_epochs):
    lossPerEpochTraining.append(train(model, device, data_loader, optimizer, criterion))
    # Update the learning rate at the end of each epoch
    scheduler.step()
    epoch_scores, epoch_truth_labels, totalLossPerEpochTestTrue, totalLossPerEpochTestBackground = testModel(model, device, data_loader_true, data_loader_total_bkg, criterion)
    scores.append(epoch_scores)
    truth_labels.append(epoch_truth_labels)
    allLossPerEpochTestTrue.append(totalLossPerEpochTestTrue)
    allLossPerEpochTestBackground.append(totalLossPerEpochTestBackground)
#Trains the GNN for 500 epochs.
# Out:
# total_loss_per_epoch: tensor(0.7263, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.6870, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.6725, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.6518, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.6374, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.6267, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.6136, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.6062, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.6009, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5955, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5917, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5908, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5899, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5892, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5885, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5879, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5872, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5864, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5858, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5851, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5845, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5838, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5831, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5825, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5819, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5814, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5809, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5804, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5799, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5794, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5790, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5786, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5781, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5777, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5773, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5769, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5765, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5761, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5757, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5753, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5749, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5745, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5741, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5738, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5734, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5730, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5726, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5722, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5719, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5715, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5712, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5708, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5705, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5701, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5698, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5694, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5691, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5688, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5685, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5681, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5678, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5675, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5672, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5669, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5666, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5663, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5661, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5658, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5655, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5652, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5650, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5647, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5644, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5642, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5640, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5637, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5635, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5633, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5630, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5627, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5625, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5622, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5620, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5617, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5615, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5613, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5611, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5610, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5608, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5607, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5605, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5603, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5601, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5598, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5595, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5592, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5590, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5588, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5586, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5584, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5583, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5582, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5581, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5580, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5580, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5579, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5578, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5577, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5576, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5574, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5571, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5568, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5564, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5561, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5560, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5559, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5559, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5559, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5559, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5559, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5558, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5556, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5553, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5550, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5547, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5546, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5544, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5543, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5542, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5541, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5541, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5540, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5540, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5539, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5539, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5538, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5537, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5536, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5534, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5531, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5528, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5525, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5523, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5521, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5520, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5520, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5520, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5521, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5523, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5524, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5523, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5521, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5517, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5514, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5511, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5508, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5506, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5504, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5502, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5502, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5502, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5502, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5502, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5501, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5499, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5496, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5494, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5493, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5494, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5492, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5489, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5485, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5483, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5481, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5478, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5477, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5475, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5475, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5476, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5476, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5478, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5479, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5479, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5479, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5478, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5475, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5472, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5470, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5467, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5464, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5462, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5460, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5459, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5459, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5458, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5457, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5457, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5457, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5458, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5460, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5461, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5462, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5464, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5463, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5461, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5457, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5454, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5450, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5448, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5447, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5446, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5445, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5445, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5445, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5445, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5445, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5446, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5447, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5448, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5448, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5449, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5448, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5447, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5445, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5442, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5440, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5438, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5437, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5436, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5435, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5435, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5435, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5435, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5435, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5435, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5435, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5436, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5436, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5437, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5438, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5439, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5439, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5439, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5438, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5435, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5433, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5430, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5428, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5427, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5426, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5426, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5426, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5426, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5426, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5426, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5426, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5426, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5426, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5427, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5427, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5427, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5428, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5429, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5429, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5429, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5428, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5427, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5425, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5423, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5421, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5420, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5418, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5418, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5418, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5417, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5418, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5418, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5418, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5419, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5419, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5419, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5419, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5419, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5419, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5419, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5419, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5419, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5420, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5420, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5421, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5420, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5419, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5418, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5416, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5414, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5412, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5411, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5411, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5410, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5410, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5410, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5411, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5411, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5411, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5411, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5412, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5412, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5412, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5412, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5412, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5413, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5413, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5413, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5414, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5415, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5415, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5415, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5414, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5412, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5410, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5408, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5406, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5405, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5405, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5405, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5405, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5405, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5406, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5406, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5406, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5407, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5407, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5407, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5407, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5408, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5408, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5409, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5409, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5409, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5409, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5409, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5407, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5405, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5403, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5402, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5401, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5400, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5400, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5401, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5401, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5402, device='cuda:0', grad_fn=<DivBackward0>)
# total_loss_per_epoch: tensor(0.5402, device='cuda:0', grad_fn=<DivBackward0>)

# %%
lossPerEpochTraining = [tensor.cpu() for tensor in lossPerEpochTraining]
allLossPerEpochTestTrue = [tensor.cpu() for tensor in allLossPerEpochTestTrue]
allLossPerEpochTestBackground = [tensor.cpu() for tensor in allLossPerEpochTestBackground]

# %%
lossPerEpochTraining = [tensor.detach().numpy() for tensor in lossPerEpochTraining]
allLossPerEpochTestTrue = [tensor.detach().numpy() for tensor in allLossPerEpochTestTrue]
allLossPerEpochTestBackground = [tensor.detach().numpy() for tensor in allLossPerEpochTestBackground]
#moves the loss back to the cpu and changes it into a numpy array

# %%
path = "./GNNCalo_cluster_all2D.pth"
#torch.save(model, path)
torch.save(model.state_dict(), path)
#Saves the trained model to an external file.

# %%
pickleData("lossDataTraining_all2D", lossPerEpochTraining)
pickleData("lossDataTestingTrue_all2D", allLossPerEpochTestTrue)
pickleData("lossDataTestingBackground_all2D", allLossPerEpochTestBackground)
pickleData("scores_all2D", scores)
pickleData("truth_labels_all2D", truth_labels)
